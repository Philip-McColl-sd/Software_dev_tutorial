# %%
from main import *

# %%
main()
# Out:
#  lets write your name in to the books!
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /home/stardust/Projects/Soft_dev_tutorial/playground.ipynb Cell 2 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/home/stardust/Projects/Soft_dev_tutorial/playground.ipynb#W1sZmlsZQ%3D%3D?line=0'>1</a> main()
#
# File ~/Projects/Soft_dev_tutorial/main.py:39, in main()
#      37 while action != "exit":
#      38     action = input("What do you want to do?\n")
# ---> 39     images.show(action)
#
# File ~/Projects/Soft_dev_tutorial/UI.py:19, in image.show(self, name)
#      17 plt.rcParams['toolbar'] = 'None'
#      18 plt.axis('off')
# ---> 19 plt.imshow(self.images[name])
#      20 plt.show(block=False)
#      21 # sleep(2)
#
# KeyError: ''
